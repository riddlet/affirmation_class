# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# /Users/triddle/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
def transitions(x,o,iw):
    """for a given essay, return the probability shifts for each word
    this has been adjusted to just return probabilities sequentially,
    instead of adding all probabilities from the same word"""
    worddeltas=[]
    endpoint = o.shape[0]
    startpoint = endpoint-np.count_nonzero(x)
    initval=o[startpoint-1]
    words = []
    probs = np.empty((0,4))
    for i in range(startpoint,endpoint):
        deltacuzofx=np.subtract(o[i],initval)
        words.append(iw[x[i]])
        probs = np.append(probs, deltacuzofx.reshape(1,4), axis=0)
        #if word in worddeltas:
        #    worddeltas[word]=worddeltas[word]+deltacuzofx
        #else:
        #    worddeltas[word]=deltacuzofx
        initval=o[i]
    return (words, probs)

# %%
def prob_reshape(x,o,iw):
    """for a given essay, return the probabilities for each word
  """
    worddeltas=[]
    endpoint = o.shape[0]
    startpoint = endpoint-np.count_nonzero(x)
    initval=o[startpoint-1]
    words = []
    probs = np.empty((0,4))
    for i in range(startpoint,endpoint):
        #deltacuzofx=np.subtract(o[i],initval)
        words.append(iw[x[i]])
        probs = np.append(probs, o[i].reshape(1,4), axis=0)
        #if word in worddeltas:
        #    worddeltas[word]=worddeltas[word]+deltacuzofx
        #else:
        #    worddeltas[word]=deltacuzofx
        initval=o[i]
    return (words, probs)

# %%
def addtransitions(x,o,iw):
    """for each essay, get the transitions associated with each word
    return a dictionary of word transitions summed across the corpus"""
    addworddeltas={}
    for i in range(x.shape[0]):
        wd=transitions(x[i],o[i],iw)
        for key, value in wd.iteritems():
            if key in addworddeltas:
                addworddeltas[key]=addworddeltas[key]+value
            else:
                addworddeltas[key]=value
    return addworddeltas

# %%
def filtertestdata(x,y,o,t,pos):
    t=np.asarray(t)
    ynew=y[(y[:,pos]==1)]
    xnew=x[(y[:,pos]==1)]
    onew=o[(y[:,pos]==1)]
    tnew=t[(y[:,pos]==1)]
    return xnew,ynew,onew,tnew.tolist()

# %%
def filterdictionary(d,pos):
    newdic={}
    values=[]
    words=[]
    for key, value in d.iteritems():
        words.append(key)
        values.append(value[pos])
    words=[x for (y,x) in sorted(zip(values,words))]
    values=[y for (y,x) in sorted(zip(values,words))]
    newdic = dict(zip(words, values))
    return words,values,newdic

# %%
# main function - Values(-1-ALL, 0-control male, 1-control female, 2-affirmation male, 3-affirmation female)
from __future__ import division
index_word=np.load('output/model_compfinalgenderdict.npy').item()
word_index=np.load('output/model_compfinalgenderdictinv.npy').item()
testdata_output=np.load('output/model_compfinalgenderoutput.npy')
testdata_x=np.load('output/model_compfinalgenderxtestdata.npy')
testdata_y=np.load('output/model_compfinalgenderytestdata.npy')
with open('output/model_compfinalgendertextsinput.txt') as f:
    text_content = f.readlines()
filtertestdatavalue=-1
filterdictionaryvalue=1
if filtertestdatavalue!=-1:
    testdata_x,testdata_y,testdata_output,text_content=filtertestdata(testdata_x,testdata_y,testdata_output,text_content,filtertestdatavalue)
maxindexoutput=np.argmax(testdata_output,axis=1)
maxindexyval=np.argmax(testdata_y,axis=1)
accuracy=(np.count_nonzero(maxindexoutput == maxindexyval)/maxindexyval.shape[0])*100
#addwd=addtransitions(testdata_x,testdata_y,testdata_output,index_word)
#words,values,dic=filterdictionary(addwd,filterdictionaryvalue)
#accuracy
# Out:
# /Users/triddle/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:16: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.

# %% [markdown]
# - index_word is pairing of index numbers with words
# - word_index is the pairing of words with index numbers
# - testdata_output is the sequential probabilities for each of the 500 test essays
# - testdata_x is a matrix of index_word values (i.e. tells you what word is in the essay
# - testdata_y is a matrix that indicates the class for each essay
# - accuracy is not scored in the same manner as essay classification (f1 score)

# %% [markdown]
# # Model comparison model information

# %%
words=[]
essay=[]
probs = np.empty((0,4))
for i in range(0, len(testdata_x)):
    word_dists = transitions(testdata_x[i],testdata_output[i], index_word)
    words.append(word_dists[0])
    essay.append([i]*len(word_dists[0]))
    probs = np.append(probs, word_dists[1], axis=0)
df1 = pd.DataFrame({'feature': [w for e in words for w in e],
                    'prob': probs[:,0],
                    'class': ['control_m']*len(probs),
                    'essay_num': [w for e in essay for w in e]})
df2 = pd.DataFrame({'feature': [w for e in words for w in e],
                    'prob': probs[:,1],
                    'class': ['control_f']*len(probs),
                    'essay_num': [w for e in essay for w in e]})
df3 = pd.DataFrame({'feature': [w for e in words for w in e],
                    'prob': probs[:,2],
                    'class': ['aff_m']*len(probs),
                    'essay_num': [w for e in essay for w in e]})
df4 = pd.DataFrame({'feature': [w for e in words for w in e],
                    'prob': probs[:,3],
                    'class': ['aff_f']*len(probs),
                    'essay_num': [w for e in essay for w in e]})
df = pd.concat([df1,df2,df3,df4])
df.to_csv('output/nn_probs.csv', index=False, encoding='utf-8')

# %%
index_word = np.load('output/flute_iw.npy').item()
word_index = np.load('output/flute_iw_inv.npy').item()
preds = np.load('output/flute_preds.npy')
x_dat = np.load('output/flute_xdat.npy')
word_dists = transitions(x_dat[0], preds[0], index_word)
df1 = pd.DataFrame({'word':word_dists[0],
                  'prob': word_dists[1][:,0],
                   'class': ['control_m']*len(word_dists[0])})
df2 = pd.DataFrame({'word':word_dists[0],
                  'prob': word_dists[1][:,1],
                   'class': ['control_f']*len(word_dists[0])})
df3 = pd.DataFrame({'word':word_dists[0],
                  'prob': word_dists[1][:,2],
                   'class': ['aff_m']*len(word_dists[0])})
df4 = pd.DataFrame({'word':word_dists[0],
                  'prob': word_dists[1][:,3],
                   'class': ['aff_f']*len(word_dists[0])})
df = pd.concat([df1,df2,df3,df4])
df.to_csv('output/flute_probs.csv', index=False, encoding='utf-8')

# %% [markdown]
# # Justifications
# (with others)

# %%
index_word = np.load('output/mightsentiw_just.npy').item()
word_index = np.load('output/mightsentiw_inv_just.npy').item()
preds = np.load('output/mightsentpreds_just.npy')
x_dat = np.load('output/mightsentxdat_just.npy')
df = np.load('output/mightdat_just.npy')

df = pd.DataFrame(df, columns=['justification', 'text', 'value'])

# %%
words=[]
essay=[]
probs = np.empty((0,4))
prob_shifts = np.empty((0,4))
val = []
just = []
for i in range(0, len(x_dat)):
    word_dists = transitions(x_dat[i],preds[i],index_word)
    word_probs = prob_reshape(x_dat[i],preds[i],index_word)
    words.append(word_dists[0])
    essay.append([i]*len(word_dists[0]))
    val.append([df.value.loc[i]]*len(word_dists[0]))
    just.append([df.justification.loc[i]]*len(word_dists[0]))
    prob_shifts = np.append(prob_shifts, word_dists[1], axis=0)
    probs = np.append(probs, word_probs[1], axis=0)
df1 = pd.DataFrame({'word': [w for e in words for w in e],
                    'prob': probs[:,0],
                    'prob_shift': prob_shifts[:,0],
                    'class': ['control_m']*len(probs),
                    'sentence_num': [w for e in essay for w in e],
                    'just': [w for e in just for w in e],
                    'val': [p for w in val for p in w]})
df2 = pd.DataFrame({'word': [w for e in words for w in e],
                    'prob': probs[:,1],
                    'prob_shift': prob_shifts[:,1],
                    'class': ['control_f']*len(probs),
                    'sentence_num': [w for e in essay for w in e],
                    'just': [w for e in just for w in e],
                    'val': [p for w in val for p in w]})
df3 = pd.DataFrame({'word': [w for e in words for w in e],
                    'prob': probs[:,2],
                    'prob_shift': prob_shifts[:,2],
                    'class': ['aff_m']*len(probs),
                    'sentence_num': [w for e in essay for w in e],
                    'just': [w for e in just for w in e],
                    'val': [p for w in val for p in w]})
df4 = pd.DataFrame({'word': [w for e in words for w in e],
                    'prob': probs[:,3],
                    'prob_shift': prob_shifts[:,3],
                    'class': ['aff_f']*len(probs),
                    'sentence_num': [w for e in essay for w in e],
                    'just': [w for e in just for w in e],
                    'val': [p for w in val for p in w]})
df_w = pd.concat([df1,df2,df3,df4])
#df.to_csv('output/nn_probs.csv', index=False, encoding='utf-8')

# %%
df_w.to_csv('output/nnprobs_might.csv', index=False, encoding='utf-8')

# %% [markdown]
# # Justifications
# (with self)

# %%
index_word = np.load('output/testsentiw_justself.npy').item()
word_index = np.load('output/testsentiw_inv_justself.npy').item()
preds = np.load('output/testsentpreds_justself.npy')
x_dat = np.load('output/testsentxdat_justself.npy')
df = np.load('output/testdat_justself.npy')

df = pd.DataFrame(df, columns=['justification', 'text', 'value'])

# %%
words=[]
essay=[]
probs = np.empty((0,4))
prob_shifts = np.empty((0,4))
val = []
just = []
for i in range(0, len(x_dat)):
    word_dists = transitions(x_dat[i],preds[i],index_word)
    word_probs = prob_reshape(x_dat[i],preds[i],index_word)
    words.append(word_dists[0])
    essay.append([i]*len(word_dists[0]))
    val.append([df.value.loc[i]]*len(word_dists[0]))
    just.append([df.justification.loc[i]]*len(word_dists[0]))
    prob_shifts = np.append(prob_shifts, word_dists[1], axis=0)
    probs = np.append(probs, word_probs[1], axis=0)
df1 = pd.DataFrame({'word': [w for e in words for w in e],
                    'prob': probs[:,0],
                    'prob_shift': prob_shifts[:,0],
                    'class': ['control_m']*len(probs),
                    'sentence_num': [w for e in essay for w in e],
                    'just': [w for e in just for w in e],
                    'val': [p for w in val for p in w]})
df2 = pd.DataFrame({'word': [w for e in words for w in e],
                    'prob': probs[:,1],
                    'prob_shift': prob_shifts[:,1],
                    'class': ['control_f']*len(probs),
                    'sentence_num': [w for e in essay for w in e],
                    'just': [w for e in just for w in e],
                    'val': [p for w in val for p in w]})
df3 = pd.DataFrame({'word': [w for e in words for w in e],
                    'prob': probs[:,2],
                    'prob_shift': prob_shifts[:,2],
                    'class': ['aff_m']*len(probs),
                    'sentence_num': [w for e in essay for w in e],
                    'just': [w for e in just for w in e],
                    'val': [p for w in val for p in w]})
df4 = pd.DataFrame({'word': [w for e in words for w in e],
                    'prob': probs[:,3],
                    'prob_shift': prob_shifts[:,3],
                    'class': ['aff_f']*len(probs),
                    'sentence_num': [w for e in essay for w in e],
                    'just': [w for e in just for w in e],
                    'val': [p for w in val for p in w]})
df_w = pd.concat([df1,df2,df3,df4])
#df.to_csv('output/nn_probs.csv', index=False, encoding='utf-8')

# %%
df_w.to_csv('output/nnprobs_justself.csv', index=False, encoding='utf-8')

# %% [markdown]
# # Justifications
# (with others & varying certainty)

# %%
index_word = np.load('output/testsentiw_cert.npy').item()
word_index = np.load('output/testsentiw_inv_cert.npy').item()
preds = np.load('output/testsentpreds_cert.npy')
x_dat = np.load('output/testsentxdat_cert.npy')
df = np.load('output/testdat_cert.npy')

df = pd.DataFrame(df, columns=['justification', 'modifier', 'text', 'value', 'modif_type'])

# %%
words=[]
essay=[]
probs = np.empty((0,4))
prob_shifts = np.empty((0,4))
val = []
just = []
modifier = []
modifier_type = []
for i in range(0, len(x_dat)):
    word_dists = transitions(x_dat[i],preds[i],index_word)
    word_probs = prob_reshape(x_dat[i],preds[i],index_word)
    words.append(word_dists[0])
    essay.append([i]*len(word_dists[0]))
    val.append([df.value.loc[i]]*len(word_dists[0]))
    just.append([df.justification.loc[i]]*len(word_dists[0]))
    modifier.append([df.modifier.loc[i]]*len(word_dists[0]))
    modifier_type.append([df.modif_type.loc[i]]*len(word_dists[0]))
    prob_shifts = np.append(prob_shifts, word_dists[1], axis=0)
    probs = np.append(probs, word_probs[1], axis=0)
df1 = pd.DataFrame({'word': [w for e in words for w in e],
                    'prob': probs[:,0],
                    'prob_shift': prob_shifts[:,0],
                    'class': ['control_m']*len(probs),
                    'sentence_num': [w for e in essay for w in e],
                    'just': [w for e in just for w in e],
                    'val': [p for w in val for p in w],
                    'mod': [m for mod in modifier for m in mod],
                    'mod_type':[m for mod in modifier_type for m in mod]})
df2 = pd.DataFrame({'word': [w for e in words for w in e],
                    'prob': probs[:,1],
                    'prob_shift': prob_shifts[:,1],
                    'class': ['control_f']*len(probs),
                    'sentence_num': [w for e in essay for w in e],
                    'just': [w for e in just for w in e],
                    'val': [p for w in val for p in w],
                    'mod': [m for mod in modifier for m in mod],
                    'mod_type':[m for mod in modifier_type for m in mod]})
df3 = pd.DataFrame({'word': [w for e in words for w in e],
                    'prob': probs[:,2],
                    'prob_shift': prob_shifts[:,2],
                    'class': ['aff_m']*len(probs),
                    'sentence_num': [w for e in essay for w in e],
                    'just': [w for e in just for w in e],
                    'val': [p for w in val for p in w],
                    'mod': [m for mod in modifier for m in mod],
                    'mod_type':[m for mod in modifier_type for m in mod]})
df4 = pd.DataFrame({'word': [w for e in words for w in e],
                    'prob': probs[:,3],
                    'prob_shift': prob_shifts[:,3],
                    'class': ['aff_f']*len(probs),
                    'sentence_num': [w for e in essay for w in e],
                    'just': [w for e in just for w in e],
                    'val': [p for w in val for p in w],
                    'mod': [m for mod in modifier for m in mod],
                    'mod_type':[m for mod in modifier_type for m in mod]})
df_w = pd.concat([df1,df2,df3,df4])
#df.to_csv('output/nn_probs.csv', index=False, encoding='utf-8')

# %%
df_w.to_csv('output/nnprobs_just_cert.csv', index=False, encoding='utf-8')

# %%
words
# Out:
# [['athletic',
#   'ability',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'friends'],
#  ['athletic',
#   'ability',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'family'],
#  ['athletic',
#   'ability',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'grandparents'],
#  ['athletic',
#   'ability',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'parents'],
#  ['athletic',
#   'ability',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'teacher'],
#  ['athletic',
#   'ability',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'friend'],
#  ['athletic', 'ability', 'might', 'be', 'important', 'because', 'my', 'dad'],
#  ['athletic', 'ability', 'might', 'be', 'important', 'because', 'my', 'mom'],
#  ['athletic',
#   'ability',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'sister'],
#  ['athletic',
#   'ability',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'brother'],
#  ['athletic',
#   'ability',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'mother'],
#  ['athletic',
#   'ability',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'father'],
#  ['athletic',
#   'ability',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'cousin'],
#  ['athletic', 'ability', 'might', 'be', 'important', 'because', 'my', 'aunt'],
#  ['athletic', 'ability', 'might', 'be', 'important', 'because', 'my', 'uncle'],
#  ['athletic',
#   'ability',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'friends'],
#  ['athletic',
#   'ability',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'family'],
#  ['athletic',
#   'ability',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'grandparents'],
#  ['athletic',
#   'ability',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'parents'],
#  ['athletic',
#   'ability',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'teacher'],
#  ['athletic',
#   'ability',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'friend'],
#  ['athletic', 'ability', 'could', 'be', 'important', 'because', 'my', 'dad'],
#  ['athletic', 'ability', 'could', 'be', 'important', 'because', 'my', 'mom'],
#  ['athletic',
#   'ability',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'sister'],
#  ['athletic',
#   'ability',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'brother'],
#  ['athletic',
#   'ability',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'mother'],
#  ['athletic',
#   'ability',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'father'],
#  ['athletic',
#   'ability',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'cousin'],
#  ['athletic', 'ability', 'could', 'be', 'important', 'because', 'my', 'aunt'],
#  ['athletic', 'ability', 'could', 'be', 'important', 'because', 'my', 'uncle'],
#  ['athletic',
#   'ability',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'friends'],
#  ['athletic',
#   'ability',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'family'],
#  ['athletic',
#   'ability',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'grandparents'],
#  ['athletic',
#   'ability',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'parents'],
#  ['athletic',
#   'ability',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'teacher'],
#  ['athletic',
#   'ability',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'friend'],
#  ['athletic', 'ability', 'should', 'be', 'important', 'because', 'my', 'dad'],
#  ['athletic', 'ability', 'should', 'be', 'important', 'because', 'my', 'mom'],
#  ['athletic',
#   'ability',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'sister'],
#  ['athletic',
#   'ability',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'brother'],
#  ['athletic',
#   'ability',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'mother'],
#  ['athletic',
#   'ability',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'father'],
#  ['athletic',
#   'ability',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'cousin'],
#  ['athletic', 'ability', 'should', 'be', 'important', 'because', 'my', 'aunt'],
#  ['athletic',
#   'ability',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'uncle'],
#  ['athletic', 'ability', 'may', 'be', 'important', 'because', 'my', 'friends'],
#  ['athletic', 'ability', 'may', 'be', 'important', 'because', 'my', 'family'],
#  ['athletic',
#   'ability',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'grandparents'],
#  ['athletic', 'ability', 'may', 'be', 'important', 'because', 'my', 'parents'],
#  ['athletic', 'ability', 'may', 'be', 'important', 'because', 'my', 'teacher'],
#  ['athletic', 'ability', 'may', 'be', 'important', 'because', 'my', 'friend'],
#  ['athletic', 'ability', 'may', 'be', 'important', 'because', 'my', 'dad'],
#  ['athletic', 'ability', 'may', 'be', 'important', 'because', 'my', 'mom'],
#  ['athletic', 'ability', 'may', 'be', 'important', 'because', 'my', 'sister'],
#  ['athletic', 'ability', 'may', 'be', 'important', 'because', 'my', 'brother'],
#  ['athletic', 'ability', 'may', 'be', 'important', 'because', 'my', 'mother'],
#  ['athletic', 'ability', 'may', 'be', 'important', 'because', 'my', 'father'],
#  ['athletic', 'ability', 'may', 'be', 'important', 'because', 'my', 'cousin'],
#  ['athletic', 'ability', 'may', 'be', 'important', 'because', 'my', 'aunt'],
#  ['athletic', 'ability', 'may', 'be', 'important', 'because', 'my', 'uncle'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'friends'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'family'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'grandparents'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'parents'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'teacher'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'friend'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'dad'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'mom'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'sister'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'brother'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'mother'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'father'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'cousin'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'aunt'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'uncle'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'friends'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'family'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'grandparents'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'parents'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'teacher'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'friend'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'dad'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'mom'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'sister'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'brother'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'mother'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'father'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'cousin'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'aunt'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'uncle'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'friends'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'family'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'grandparents'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'parents'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'teacher'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'friend'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'dad'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'mom'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'sister'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'brother'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'mother'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'father'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'cousin'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'aunt'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'uncle'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'friends'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'family'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'grandparents'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'parents'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'teacher'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'friend'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'dad'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'mom'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'sister'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'brother'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'mother'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'father'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'cousin'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'aunt'],
#  ['athletic', 'ability', 'important', 'because', 'my', 'uncle'],
#  ['art', 'might', 'be', 'important', 'because', 'my', 'friends'],
#  ['art', 'might', 'be', 'important', 'because', 'my', 'family'],
#  ['art', 'might', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['art', 'might', 'be', 'important', 'because', 'my', 'parents'],
#  ['art', 'might', 'be', 'important', 'because', 'my', 'teacher'],
#  ['art', 'might', 'be', 'important', 'because', 'my', 'friend'],
#  ['art', 'might', 'be', 'important', 'because', 'my', 'dad'],
#  ['art', 'might', 'be', 'important', 'because', 'my', 'mom'],
#  ['art', 'might', 'be', 'important', 'because', 'my', 'sister'],
#  ['art', 'might', 'be', 'important', 'because', 'my', 'brother'],
#  ['art', 'might', 'be', 'important', 'because', 'my', 'mother'],
#  ['art', 'might', 'be', 'important', 'because', 'my', 'father'],
#  ['art', 'might', 'be', 'important', 'because', 'my', 'cousin'],
#  ['art', 'might', 'be', 'important', 'because', 'my', 'aunt'],
#  ['art', 'might', 'be', 'important', 'because', 'my', 'uncle'],
#  ['art', 'could', 'be', 'important', 'because', 'my', 'friends'],
#  ['art', 'could', 'be', 'important', 'because', 'my', 'family'],
#  ['art', 'could', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['art', 'could', 'be', 'important', 'because', 'my', 'parents'],
#  ['art', 'could', 'be', 'important', 'because', 'my', 'teacher'],
#  ['art', 'could', 'be', 'important', 'because', 'my', 'friend'],
#  ['art', 'could', 'be', 'important', 'because', 'my', 'dad'],
#  ['art', 'could', 'be', 'important', 'because', 'my', 'mom'],
#  ['art', 'could', 'be', 'important', 'because', 'my', 'sister'],
#  ['art', 'could', 'be', 'important', 'because', 'my', 'brother'],
#  ['art', 'could', 'be', 'important', 'because', 'my', 'mother'],
#  ['art', 'could', 'be', 'important', 'because', 'my', 'father'],
#  ['art', 'could', 'be', 'important', 'because', 'my', 'cousin'],
#  ['art', 'could', 'be', 'important', 'because', 'my', 'aunt'],
#  ['art', 'could', 'be', 'important', 'because', 'my', 'uncle'],
#  ['art', 'should', 'be', 'important', 'because', 'my', 'friends'],
#  ['art', 'should', 'be', 'important', 'because', 'my', 'family'],
#  ['art', 'should', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['art', 'should', 'be', 'important', 'because', 'my', 'parents'],
#  ['art', 'should', 'be', 'important', 'because', 'my', 'teacher'],
#  ['art', 'should', 'be', 'important', 'because', 'my', 'friend'],
#  ['art', 'should', 'be', 'important', 'because', 'my', 'dad'],
#  ['art', 'should', 'be', 'important', 'because', 'my', 'mom'],
#  ['art', 'should', 'be', 'important', 'because', 'my', 'sister'],
#  ['art', 'should', 'be', 'important', 'because', 'my', 'brother'],
#  ['art', 'should', 'be', 'important', 'because', 'my', 'mother'],
#  ['art', 'should', 'be', 'important', 'because', 'my', 'father'],
#  ['art', 'should', 'be', 'important', 'because', 'my', 'cousin'],
#  ['art', 'should', 'be', 'important', 'because', 'my', 'aunt'],
#  ['art', 'should', 'be', 'important', 'because', 'my', 'uncle'],
#  ['art', 'may', 'be', 'important', 'because', 'my', 'friends'],
#  ['art', 'may', 'be', 'important', 'because', 'my', 'family'],
#  ['art', 'may', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['art', 'may', 'be', 'important', 'because', 'my', 'parents'],
#  ['art', 'may', 'be', 'important', 'because', 'my', 'teacher'],
#  ['art', 'may', 'be', 'important', 'because', 'my', 'friend'],
#  ['art', 'may', 'be', 'important', 'because', 'my', 'dad'],
#  ['art', 'may', 'be', 'important', 'because', 'my', 'mom'],
#  ['art', 'may', 'be', 'important', 'because', 'my', 'sister'],
#  ['art', 'may', 'be', 'important', 'because', 'my', 'brother'],
#  ['art', 'may', 'be', 'important', 'because', 'my', 'mother'],
#  ['art', 'may', 'be', 'important', 'because', 'my', 'father'],
#  ['art', 'may', 'be', 'important', 'because', 'my', 'cousin'],
#  ['art', 'may', 'be', 'important', 'because', 'my', 'aunt'],
#  ['art', 'may', 'be', 'important', 'because', 'my', 'uncle'],
#  ['art', 'important', 'because', 'my', 'friends'],
#  ['art', 'important', 'because', 'my', 'family'],
#  ['art', 'important', 'because', 'my', 'grandparents'],
#  ['art', 'important', 'because', 'my', 'parents'],
#  ['art', 'important', 'because', 'my', 'teacher'],
#  ['art', 'important', 'because', 'my', 'friend'],
#  ['art', 'important', 'because', 'my', 'dad'],
#  ['art', 'important', 'because', 'my', 'mom'],
#  ['art', 'important', 'because', 'my', 'sister'],
#  ['art', 'important', 'because', 'my', 'brother'],
#  ['art', 'important', 'because', 'my', 'mother'],
#  ['art', 'important', 'because', 'my', 'father'],
#  ['art', 'important', 'because', 'my', 'cousin'],
#  ['art', 'important', 'because', 'my', 'aunt'],
#  ['art', 'important', 'because', 'my', 'uncle'],
#  ['art', 'important', 'because', 'my', 'friends'],
#  ['art', 'important', 'because', 'my', 'family'],
#  ['art', 'important', 'because', 'my', 'grandparents'],
#  ['art', 'important', 'because', 'my', 'parents'],
#  ['art', 'important', 'because', 'my', 'teacher'],
#  ['art', 'important', 'because', 'my', 'friend'],
#  ['art', 'important', 'because', 'my', 'dad'],
#  ['art', 'important', 'because', 'my', 'mom'],
#  ['art', 'important', 'because', 'my', 'sister'],
#  ['art', 'important', 'because', 'my', 'brother'],
#  ['art', 'important', 'because', 'my', 'mother'],
#  ['art', 'important', 'because', 'my', 'father'],
#  ['art', 'important', 'because', 'my', 'cousin'],
#  ['art', 'important', 'because', 'my', 'aunt'],
#  ['art', 'important', 'because', 'my', 'uncle'],
#  ['art', 'important', 'because', 'my', 'friends'],
#  ['art', 'important', 'because', 'my', 'family'],
#  ['art', 'important', 'because', 'my', 'grandparents'],
#  ['art', 'important', 'because', 'my', 'parents'],
#  ['art', 'important', 'because', 'my', 'teacher'],
#  ['art', 'important', 'because', 'my', 'friend'],
#  ['art', 'important', 'because', 'my', 'dad'],
#  ['art', 'important', 'because', 'my', 'mom'],
#  ['art', 'important', 'because', 'my', 'sister'],
#  ['art', 'important', 'because', 'my', 'brother'],
#  ['art', 'important', 'because', 'my', 'mother'],
#  ['art', 'important', 'because', 'my', 'father'],
#  ['art', 'important', 'because', 'my', 'cousin'],
#  ['art', 'important', 'because', 'my', 'aunt'],
#  ['art', 'important', 'because', 'my', 'uncle'],
#  ['art', 'important', 'because', 'my', 'friends'],
#  ['art', 'important', 'because', 'my', 'family'],
#  ['art', 'important', 'because', 'my', 'grandparents'],
#  ['art', 'important', 'because', 'my', 'parents'],
#  ['art', 'important', 'because', 'my', 'teacher'],
#  ['art', 'important', 'because', 'my', 'friend'],
#  ['art', 'important', 'because', 'my', 'dad'],
#  ['art', 'important', 'because', 'my', 'mom'],
#  ['art', 'important', 'because', 'my', 'sister'],
#  ['art', 'important', 'because', 'my', 'brother'],
#  ['art', 'important', 'because', 'my', 'mother'],
#  ['art', 'important', 'because', 'my', 'father'],
#  ['art', 'important', 'because', 'my', 'cousin'],
#  ['art', 'important', 'because', 'my', 'aunt'],
#  ['art', 'important', 'because', 'my', 'uncle'],
#  ['being', 'smart', 'might', 'be', 'important', 'because', 'my', 'friends'],
#  ['being', 'smart', 'might', 'be', 'important', 'because', 'my', 'family'],
#  ['being',
#   'smart',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'grandparents'],
#  ['being', 'smart', 'might', 'be', 'important', 'because', 'my', 'parents'],
#  ['being', 'smart', 'might', 'be', 'important', 'because', 'my', 'teacher'],
#  ['being', 'smart', 'might', 'be', 'important', 'because', 'my', 'friend'],
#  ['being', 'smart', 'might', 'be', 'important', 'because', 'my', 'dad'],
#  ['being', 'smart', 'might', 'be', 'important', 'because', 'my', 'mom'],
#  ['being', 'smart', 'might', 'be', 'important', 'because', 'my', 'sister'],
#  ['being', 'smart', 'might', 'be', 'important', 'because', 'my', 'brother'],
#  ['being', 'smart', 'might', 'be', 'important', 'because', 'my', 'mother'],
#  ['being', 'smart', 'might', 'be', 'important', 'because', 'my', 'father'],
#  ['being', 'smart', 'might', 'be', 'important', 'because', 'my', 'cousin'],
#  ['being', 'smart', 'might', 'be', 'important', 'because', 'my', 'aunt'],
#  ['being', 'smart', 'might', 'be', 'important', 'because', 'my', 'uncle'],
#  ['being', 'smart', 'could', 'be', 'important', 'because', 'my', 'friends'],
#  ['being', 'smart', 'could', 'be', 'important', 'because', 'my', 'family'],
#  ['being',
#   'smart',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'grandparents'],
#  ['being', 'smart', 'could', 'be', 'important', 'because', 'my', 'parents'],
#  ['being', 'smart', 'could', 'be', 'important', 'because', 'my', 'teacher'],
#  ['being', 'smart', 'could', 'be', 'important', 'because', 'my', 'friend'],
#  ['being', 'smart', 'could', 'be', 'important', 'because', 'my', 'dad'],
#  ['being', 'smart', 'could', 'be', 'important', 'because', 'my', 'mom'],
#  ['being', 'smart', 'could', 'be', 'important', 'because', 'my', 'sister'],
#  ['being', 'smart', 'could', 'be', 'important', 'because', 'my', 'brother'],
#  ['being', 'smart', 'could', 'be', 'important', 'because', 'my', 'mother'],
#  ['being', 'smart', 'could', 'be', 'important', 'because', 'my', 'father'],
#  ['being', 'smart', 'could', 'be', 'important', 'because', 'my', 'cousin'],
#  ['being', 'smart', 'could', 'be', 'important', 'because', 'my', 'aunt'],
#  ['being', 'smart', 'could', 'be', 'important', 'because', 'my', 'uncle'],
#  ['being', 'smart', 'should', 'be', 'important', 'because', 'my', 'friends'],
#  ['being', 'smart', 'should', 'be', 'important', 'because', 'my', 'family'],
#  ['being',
#   'smart',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'grandparents'],
#  ['being', 'smart', 'should', 'be', 'important', 'because', 'my', 'parents'],
#  ['being', 'smart', 'should', 'be', 'important', 'because', 'my', 'teacher'],
#  ['being', 'smart', 'should', 'be', 'important', 'because', 'my', 'friend'],
#  ['being', 'smart', 'should', 'be', 'important', 'because', 'my', 'dad'],
#  ['being', 'smart', 'should', 'be', 'important', 'because', 'my', 'mom'],
#  ['being', 'smart', 'should', 'be', 'important', 'because', 'my', 'sister'],
#  ['being', 'smart', 'should', 'be', 'important', 'because', 'my', 'brother'],
#  ['being', 'smart', 'should', 'be', 'important', 'because', 'my', 'mother'],
#  ['being', 'smart', 'should', 'be', 'important', 'because', 'my', 'father'],
#  ['being', 'smart', 'should', 'be', 'important', 'because', 'my', 'cousin'],
#  ['being', 'smart', 'should', 'be', 'important', 'because', 'my', 'aunt'],
#  ['being', 'smart', 'should', 'be', 'important', 'because', 'my', 'uncle'],
#  ['being', 'smart', 'may', 'be', 'important', 'because', 'my', 'friends'],
#  ['being', 'smart', 'may', 'be', 'important', 'because', 'my', 'family'],
#  ['being', 'smart', 'may', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['being', 'smart', 'may', 'be', 'important', 'because', 'my', 'parents'],
#  ['being', 'smart', 'may', 'be', 'important', 'because', 'my', 'teacher'],
#  ['being', 'smart', 'may', 'be', 'important', 'because', 'my', 'friend'],
#  ['being', 'smart', 'may', 'be', 'important', 'because', 'my', 'dad'],
#  ['being', 'smart', 'may', 'be', 'important', 'because', 'my', 'mom'],
#  ['being', 'smart', 'may', 'be', 'important', 'because', 'my', 'sister'],
#  ['being', 'smart', 'may', 'be', 'important', 'because', 'my', 'brother'],
#  ['being', 'smart', 'may', 'be', 'important', 'because', 'my', 'mother'],
#  ['being', 'smart', 'may', 'be', 'important', 'because', 'my', 'father'],
#  ['being', 'smart', 'may', 'be', 'important', 'because', 'my', 'cousin'],
#  ['being', 'smart', 'may', 'be', 'important', 'because', 'my', 'aunt'],
#  ['being', 'smart', 'may', 'be', 'important', 'because', 'my', 'uncle'],
#  ['being', 'smart', 'important', 'because', 'my', 'friends'],
#  ['being', 'smart', 'important', 'because', 'my', 'family'],
#  ['being', 'smart', 'important', 'because', 'my', 'grandparents'],
#  ['being', 'smart', 'important', 'because', 'my', 'parents'],
#  ['being', 'smart', 'important', 'because', 'my', 'teacher'],
#  ['being', 'smart', 'important', 'because', 'my', 'friend'],
#  ['being', 'smart', 'important', 'because', 'my', 'dad'],
#  ['being', 'smart', 'important', 'because', 'my', 'mom'],
#  ['being', 'smart', 'important', 'because', 'my', 'sister'],
#  ['being', 'smart', 'important', 'because', 'my', 'brother'],
#  ['being', 'smart', 'important', 'because', 'my', 'mother'],
#  ['being', 'smart', 'important', 'because', 'my', 'father'],
#  ['being', 'smart', 'important', 'because', 'my', 'cousin'],
#  ['being', 'smart', 'important', 'because', 'my', 'aunt'],
#  ['being', 'smart', 'important', 'because', 'my', 'uncle'],
#  ['being', 'smart', 'important', 'because', 'my', 'friends'],
#  ['being', 'smart', 'important', 'because', 'my', 'family'],
#  ['being', 'smart', 'important', 'because', 'my', 'grandparents'],
#  ['being', 'smart', 'important', 'because', 'my', 'parents'],
#  ['being', 'smart', 'important', 'because', 'my', 'teacher'],
#  ['being', 'smart', 'important', 'because', 'my', 'friend'],
#  ['being', 'smart', 'important', 'because', 'my', 'dad'],
#  ['being', 'smart', 'important', 'because', 'my', 'mom'],
#  ['being', 'smart', 'important', 'because', 'my', 'sister'],
#  ['being', 'smart', 'important', 'because', 'my', 'brother'],
#  ['being', 'smart', 'important', 'because', 'my', 'mother'],
#  ['being', 'smart', 'important', 'because', 'my', 'father'],
#  ['being', 'smart', 'important', 'because', 'my', 'cousin'],
#  ['being', 'smart', 'important', 'because', 'my', 'aunt'],
#  ['being', 'smart', 'important', 'because', 'my', 'uncle'],
#  ['being', 'smart', 'important', 'because', 'my', 'friends'],
#  ['being', 'smart', 'important', 'because', 'my', 'family'],
#  ['being', 'smart', 'important', 'because', 'my', 'grandparents'],
#  ['being', 'smart', 'important', 'because', 'my', 'parents'],
#  ['being', 'smart', 'important', 'because', 'my', 'teacher'],
#  ['being', 'smart', 'important', 'because', 'my', 'friend'],
#  ['being', 'smart', 'important', 'because', 'my', 'dad'],
#  ['being', 'smart', 'important', 'because', 'my', 'mom'],
#  ['being', 'smart', 'important', 'because', 'my', 'sister'],
#  ['being', 'smart', 'important', 'because', 'my', 'brother'],
#  ['being', 'smart', 'important', 'because', 'my', 'mother'],
#  ['being', 'smart', 'important', 'because', 'my', 'father'],
#  ['being', 'smart', 'important', 'because', 'my', 'cousin'],
#  ['being', 'smart', 'important', 'because', 'my', 'aunt'],
#  ['being', 'smart', 'important', 'because', 'my', 'uncle'],
#  ['being', 'smart', 'important', 'because', 'my', 'friends'],
#  ['being', 'smart', 'important', 'because', 'my', 'family'],
#  ['being', 'smart', 'important', 'because', 'my', 'grandparents'],
#  ['being', 'smart', 'important', 'because', 'my', 'parents'],
#  ['being', 'smart', 'important', 'because', 'my', 'teacher'],
#  ['being', 'smart', 'important', 'because', 'my', 'friend'],
#  ['being', 'smart', 'important', 'because', 'my', 'dad'],
#  ['being', 'smart', 'important', 'because', 'my', 'mom'],
#  ['being', 'smart', 'important', 'because', 'my', 'sister'],
#  ['being', 'smart', 'important', 'because', 'my', 'brother'],
#  ['being', 'smart', 'important', 'because', 'my', 'mother'],
#  ['being', 'smart', 'important', 'because', 'my', 'father'],
#  ['being', 'smart', 'important', 'because', 'my', 'cousin'],
#  ['being', 'smart', 'important', 'because', 'my', 'aunt'],
#  ['being', 'smart', 'important', 'because', 'my', 'uncle'],
#  ['getting',
#   'good',
#   'grades',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'friends'],
#  ['getting',
#   'good',
#   'grades',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'family'],
#  ['getting',
#   'good',
#   'grades',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'grandparents'],
#  ['getting',
#   'good',
#   'grades',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'parents'],
#  ['getting',
#   'good',
#   'grades',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'teacher'],
#  ['getting',
#   'good',
#   'grades',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'friend'],
#  ['getting',
#   'good',
#   'grades',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'dad'],
#  ['getting',
#   'good',
#   'grades',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'mom'],
#  ['getting',
#   'good',
#   'grades',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'sister'],
#  ['getting',
#   'good',
#   'grades',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'brother'],
#  ['getting',
#   'good',
#   'grades',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'mother'],
#  ['getting',
#   'good',
#   'grades',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'father'],
#  ['getting',
#   'good',
#   'grades',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'cousin'],
#  ['getting',
#   'good',
#   'grades',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'aunt'],
#  ['getting',
#   'good',
#   'grades',
#   'might',
#   'be',
#   'important',
#   'because',
#   'my',
#   'uncle'],
#  ['getting',
#   'good',
#   'grades',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'friends'],
#  ['getting',
#   'good',
#   'grades',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'family'],
#  ['getting',
#   'good',
#   'grades',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'grandparents'],
#  ['getting',
#   'good',
#   'grades',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'parents'],
#  ['getting',
#   'good',
#   'grades',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'teacher'],
#  ['getting',
#   'good',
#   'grades',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'friend'],
#  ['getting',
#   'good',
#   'grades',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'dad'],
#  ['getting',
#   'good',
#   'grades',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'mom'],
#  ['getting',
#   'good',
#   'grades',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'sister'],
#  ['getting',
#   'good',
#   'grades',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'brother'],
#  ['getting',
#   'good',
#   'grades',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'mother'],
#  ['getting',
#   'good',
#   'grades',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'father'],
#  ['getting',
#   'good',
#   'grades',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'cousin'],
#  ['getting',
#   'good',
#   'grades',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'aunt'],
#  ['getting',
#   'good',
#   'grades',
#   'could',
#   'be',
#   'important',
#   'because',
#   'my',
#   'uncle'],
#  ['getting',
#   'good',
#   'grades',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'friends'],
#  ['getting',
#   'good',
#   'grades',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'family'],
#  ['getting',
#   'good',
#   'grades',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'grandparents'],
#  ['getting',
#   'good',
#   'grades',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'parents'],
#  ['getting',
#   'good',
#   'grades',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'teacher'],
#  ['getting',
#   'good',
#   'grades',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'friend'],
#  ['getting',
#   'good',
#   'grades',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'dad'],
#  ['getting',
#   'good',
#   'grades',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'mom'],
#  ['getting',
#   'good',
#   'grades',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'sister'],
#  ['getting',
#   'good',
#   'grades',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'brother'],
#  ['getting',
#   'good',
#   'grades',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'mother'],
#  ['getting',
#   'good',
#   'grades',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'father'],
#  ['getting',
#   'good',
#   'grades',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'cousin'],
#  ['getting',
#   'good',
#   'grades',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'aunt'],
#  ['getting',
#   'good',
#   'grades',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'uncle'],
#  ['getting',
#   'good',
#   'grades',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'friends'],
#  ['getting',
#   'good',
#   'grades',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'family'],
#  ['getting',
#   'good',
#   'grades',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'grandparents'],
#  ['getting',
#   'good',
#   'grades',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'parents'],
#  ['getting',
#   'good',
#   'grades',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'teacher'],
#  ['getting',
#   'good',
#   'grades',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'friend'],
#  ['getting',
#   'good',
#   'grades',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'dad'],
#  ['getting',
#   'good',
#   'grades',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'mom'],
#  ['getting',
#   'good',
#   'grades',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'sister'],
#  ['getting',
#   'good',
#   'grades',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'brother'],
#  ['getting',
#   'good',
#   'grades',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'mother'],
#  ['getting',
#   'good',
#   'grades',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'father'],
#  ['getting',
#   'good',
#   'grades',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'cousin'],
#  ['getting',
#   'good',
#   'grades',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'aunt'],
#  ['getting',
#   'good',
#   'grades',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'uncle'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'friends'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'family'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'grandparents'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'parents'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'teacher'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'friend'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'dad'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'mom'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'sister'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'brother'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'mother'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'father'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'cousin'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'aunt'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'uncle'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'friends'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'family'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'grandparents'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'parents'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'teacher'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'friend'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'dad'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'mom'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'sister'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'brother'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'mother'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'father'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'cousin'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'aunt'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'uncle'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'friends'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'family'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'grandparents'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'parents'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'teacher'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'friend'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'dad'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'mom'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'sister'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'brother'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'mother'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'father'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'cousin'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'aunt'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'uncle'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'friends'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'family'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'grandparents'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'parents'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'teacher'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'friend'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'dad'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'mom'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'sister'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'brother'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'mother'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'father'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'cousin'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'aunt'],
#  ['getting', 'good', 'grades', 'important', 'because', 'my', 'uncle'],
#  ['creativity', 'might', 'be', 'important', 'because', 'my', 'friends'],
#  ['creativity', 'might', 'be', 'important', 'because', 'my', 'family'],
#  ['creativity', 'might', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['creativity', 'might', 'be', 'important', 'because', 'my', 'parents'],
#  ['creativity', 'might', 'be', 'important', 'because', 'my', 'teacher'],
#  ['creativity', 'might', 'be', 'important', 'because', 'my', 'friend'],
#  ['creativity', 'might', 'be', 'important', 'because', 'my', 'dad'],
#  ['creativity', 'might', 'be', 'important', 'because', 'my', 'mom'],
#  ['creativity', 'might', 'be', 'important', 'because', 'my', 'sister'],
#  ['creativity', 'might', 'be', 'important', 'because', 'my', 'brother'],
#  ['creativity', 'might', 'be', 'important', 'because', 'my', 'mother'],
#  ['creativity', 'might', 'be', 'important', 'because', 'my', 'father'],
#  ['creativity', 'might', 'be', 'important', 'because', 'my', 'cousin'],
#  ['creativity', 'might', 'be', 'important', 'because', 'my', 'aunt'],
#  ['creativity', 'might', 'be', 'important', 'because', 'my', 'uncle'],
#  ['creativity', 'could', 'be', 'important', 'because', 'my', 'friends'],
#  ['creativity', 'could', 'be', 'important', 'because', 'my', 'family'],
#  ['creativity', 'could', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['creativity', 'could', 'be', 'important', 'because', 'my', 'parents'],
#  ['creativity', 'could', 'be', 'important', 'because', 'my', 'teacher'],
#  ['creativity', 'could', 'be', 'important', 'because', 'my', 'friend'],
#  ['creativity', 'could', 'be', 'important', 'because', 'my', 'dad'],
#  ['creativity', 'could', 'be', 'important', 'because', 'my', 'mom'],
#  ['creativity', 'could', 'be', 'important', 'because', 'my', 'sister'],
#  ['creativity', 'could', 'be', 'important', 'because', 'my', 'brother'],
#  ['creativity', 'could', 'be', 'important', 'because', 'my', 'mother'],
#  ['creativity', 'could', 'be', 'important', 'because', 'my', 'father'],
#  ['creativity', 'could', 'be', 'important', 'because', 'my', 'cousin'],
#  ['creativity', 'could', 'be', 'important', 'because', 'my', 'aunt'],
#  ['creativity', 'could', 'be', 'important', 'because', 'my', 'uncle'],
#  ['creativity', 'should', 'be', 'important', 'because', 'my', 'friends'],
#  ['creativity', 'should', 'be', 'important', 'because', 'my', 'family'],
#  ['creativity', 'should', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['creativity', 'should', 'be', 'important', 'because', 'my', 'parents'],
#  ['creativity', 'should', 'be', 'important', 'because', 'my', 'teacher'],
#  ['creativity', 'should', 'be', 'important', 'because', 'my', 'friend'],
#  ['creativity', 'should', 'be', 'important', 'because', 'my', 'dad'],
#  ['creativity', 'should', 'be', 'important', 'because', 'my', 'mom'],
#  ['creativity', 'should', 'be', 'important', 'because', 'my', 'sister'],
#  ['creativity', 'should', 'be', 'important', 'because', 'my', 'brother'],
#  ['creativity', 'should', 'be', 'important', 'because', 'my', 'mother'],
#  ['creativity', 'should', 'be', 'important', 'because', 'my', 'father'],
#  ['creativity', 'should', 'be', 'important', 'because', 'my', 'cousin'],
#  ['creativity', 'should', 'be', 'important', 'because', 'my', 'aunt'],
#  ['creativity', 'should', 'be', 'important', 'because', 'my', 'uncle'],
#  ['creativity', 'may', 'be', 'important', 'because', 'my', 'friends'],
#  ['creativity', 'may', 'be', 'important', 'because', 'my', 'family'],
#  ['creativity', 'may', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['creativity', 'may', 'be', 'important', 'because', 'my', 'parents'],
#  ['creativity', 'may', 'be', 'important', 'because', 'my', 'teacher'],
#  ['creativity', 'may', 'be', 'important', 'because', 'my', 'friend'],
#  ['creativity', 'may', 'be', 'important', 'because', 'my', 'dad'],
#  ['creativity', 'may', 'be', 'important', 'because', 'my', 'mom'],
#  ['creativity', 'may', 'be', 'important', 'because', 'my', 'sister'],
#  ['creativity', 'may', 'be', 'important', 'because', 'my', 'brother'],
#  ['creativity', 'may', 'be', 'important', 'because', 'my', 'mother'],
#  ['creativity', 'may', 'be', 'important', 'because', 'my', 'father'],
#  ['creativity', 'may', 'be', 'important', 'because', 'my', 'cousin'],
#  ['creativity', 'may', 'be', 'important', 'because', 'my', 'aunt'],
#  ['creativity', 'may', 'be', 'important', 'because', 'my', 'uncle'],
#  ['creativity', 'important', 'because', 'my', 'friends'],
#  ['creativity', 'important', 'because', 'my', 'family'],
#  ['creativity', 'important', 'because', 'my', 'grandparents'],
#  ['creativity', 'important', 'because', 'my', 'parents'],
#  ['creativity', 'important', 'because', 'my', 'teacher'],
#  ['creativity', 'important', 'because', 'my', 'friend'],
#  ['creativity', 'important', 'because', 'my', 'dad'],
#  ['creativity', 'important', 'because', 'my', 'mom'],
#  ['creativity', 'important', 'because', 'my', 'sister'],
#  ['creativity', 'important', 'because', 'my', 'brother'],
#  ['creativity', 'important', 'because', 'my', 'mother'],
#  ['creativity', 'important', 'because', 'my', 'father'],
#  ['creativity', 'important', 'because', 'my', 'cousin'],
#  ['creativity', 'important', 'because', 'my', 'aunt'],
#  ['creativity', 'important', 'because', 'my', 'uncle'],
#  ['creativity', 'important', 'because', 'my', 'friends'],
#  ['creativity', 'important', 'because', 'my', 'family'],
#  ['creativity', 'important', 'because', 'my', 'grandparents'],
#  ['creativity', 'important', 'because', 'my', 'parents'],
#  ['creativity', 'important', 'because', 'my', 'teacher'],
#  ['creativity', 'important', 'because', 'my', 'friend'],
#  ['creativity', 'important', 'because', 'my', 'dad'],
#  ['creativity', 'important', 'because', 'my', 'mom'],
#  ['creativity', 'important', 'because', 'my', 'sister'],
#  ['creativity', 'important', 'because', 'my', 'brother'],
#  ['creativity', 'important', 'because', 'my', 'mother'],
#  ['creativity', 'important', 'because', 'my', 'father'],
#  ['creativity', 'important', 'because', 'my', 'cousin'],
#  ['creativity', 'important', 'because', 'my', 'aunt'],
#  ['creativity', 'important', 'because', 'my', 'uncle'],
#  ['creativity', 'important', 'because', 'my', 'friends'],
#  ['creativity', 'important', 'because', 'my', 'family'],
#  ['creativity', 'important', 'because', 'my', 'grandparents'],
#  ['creativity', 'important', 'because', 'my', 'parents'],
#  ['creativity', 'important', 'because', 'my', 'teacher'],
#  ['creativity', 'important', 'because', 'my', 'friend'],
#  ['creativity', 'important', 'because', 'my', 'dad'],
#  ['creativity', 'important', 'because', 'my', 'mom'],
#  ['creativity', 'important', 'because', 'my', 'sister'],
#  ['creativity', 'important', 'because', 'my', 'brother'],
#  ['creativity', 'important', 'because', 'my', 'mother'],
#  ['creativity', 'important', 'because', 'my', 'father'],
#  ['creativity', 'important', 'because', 'my', 'cousin'],
#  ['creativity', 'important', 'because', 'my', 'aunt'],
#  ['creativity', 'important', 'because', 'my', 'uncle'],
#  ['creativity', 'important', 'because', 'my', 'friends'],
#  ['creativity', 'important', 'because', 'my', 'family'],
#  ['creativity', 'important', 'because', 'my', 'grandparents'],
#  ['creativity', 'important', 'because', 'my', 'parents'],
#  ['creativity', 'important', 'because', 'my', 'teacher'],
#  ['creativity', 'important', 'because', 'my', 'friend'],
#  ['creativity', 'important', 'because', 'my', 'dad'],
#  ['creativity', 'important', 'because', 'my', 'mom'],
#  ['creativity', 'important', 'because', 'my', 'sister'],
#  ['creativity', 'important', 'because', 'my', 'brother'],
#  ['creativity', 'important', 'because', 'my', 'mother'],
#  ['creativity', 'important', 'because', 'my', 'father'],
#  ['creativity', 'important', 'because', 'my', 'cousin'],
#  ['creativity', 'important', 'because', 'my', 'aunt'],
#  ['creativity', 'important', 'because', 'my', 'uncle'],
#  ['independence', 'might', 'be', 'important', 'because', 'my', 'friends'],
#  ['independence', 'might', 'be', 'important', 'because', 'my', 'family'],
#  ['independence', 'might', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['independence', 'might', 'be', 'important', 'because', 'my', 'parents'],
#  ['independence', 'might', 'be', 'important', 'because', 'my', 'teacher'],
#  ['independence', 'might', 'be', 'important', 'because', 'my', 'friend'],
#  ['independence', 'might', 'be', 'important', 'because', 'my', 'dad'],
#  ['independence', 'might', 'be', 'important', 'because', 'my', 'mom'],
#  ['independence', 'might', 'be', 'important', 'because', 'my', 'sister'],
#  ['independence', 'might', 'be', 'important', 'because', 'my', 'brother'],
#  ['independence', 'might', 'be', 'important', 'because', 'my', 'mother'],
#  ['independence', 'might', 'be', 'important', 'because', 'my', 'father'],
#  ['independence', 'might', 'be', 'important', 'because', 'my', 'cousin'],
#  ['independence', 'might', 'be', 'important', 'because', 'my', 'aunt'],
#  ['independence', 'might', 'be', 'important', 'because', 'my', 'uncle'],
#  ['independence', 'could', 'be', 'important', 'because', 'my', 'friends'],
#  ['independence', 'could', 'be', 'important', 'because', 'my', 'family'],
#  ['independence', 'could', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['independence', 'could', 'be', 'important', 'because', 'my', 'parents'],
#  ['independence', 'could', 'be', 'important', 'because', 'my', 'teacher'],
#  ['independence', 'could', 'be', 'important', 'because', 'my', 'friend'],
#  ['independence', 'could', 'be', 'important', 'because', 'my', 'dad'],
#  ['independence', 'could', 'be', 'important', 'because', 'my', 'mom'],
#  ['independence', 'could', 'be', 'important', 'because', 'my', 'sister'],
#  ['independence', 'could', 'be', 'important', 'because', 'my', 'brother'],
#  ['independence', 'could', 'be', 'important', 'because', 'my', 'mother'],
#  ['independence', 'could', 'be', 'important', 'because', 'my', 'father'],
#  ['independence', 'could', 'be', 'important', 'because', 'my', 'cousin'],
#  ['independence', 'could', 'be', 'important', 'because', 'my', 'aunt'],
#  ['independence', 'could', 'be', 'important', 'because', 'my', 'uncle'],
#  ['independence', 'should', 'be', 'important', 'because', 'my', 'friends'],
#  ['independence', 'should', 'be', 'important', 'because', 'my', 'family'],
#  ['independence',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'grandparents'],
#  ['independence', 'should', 'be', 'important', 'because', 'my', 'parents'],
#  ['independence', 'should', 'be', 'important', 'because', 'my', 'teacher'],
#  ['independence', 'should', 'be', 'important', 'because', 'my', 'friend'],
#  ['independence', 'should', 'be', 'important', 'because', 'my', 'dad'],
#  ['independence', 'should', 'be', 'important', 'because', 'my', 'mom'],
#  ['independence', 'should', 'be', 'important', 'because', 'my', 'sister'],
#  ['independence', 'should', 'be', 'important', 'because', 'my', 'brother'],
#  ['independence', 'should', 'be', 'important', 'because', 'my', 'mother'],
#  ['independence', 'should', 'be', 'important', 'because', 'my', 'father'],
#  ['independence', 'should', 'be', 'important', 'because', 'my', 'cousin'],
#  ['independence', 'should', 'be', 'important', 'because', 'my', 'aunt'],
#  ['independence', 'should', 'be', 'important', 'because', 'my', 'uncle'],
#  ['independence', 'may', 'be', 'important', 'because', 'my', 'friends'],
#  ['independence', 'may', 'be', 'important', 'because', 'my', 'family'],
#  ['independence', 'may', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['independence', 'may', 'be', 'important', 'because', 'my', 'parents'],
#  ['independence', 'may', 'be', 'important', 'because', 'my', 'teacher'],
#  ['independence', 'may', 'be', 'important', 'because', 'my', 'friend'],
#  ['independence', 'may', 'be', 'important', 'because', 'my', 'dad'],
#  ['independence', 'may', 'be', 'important', 'because', 'my', 'mom'],
#  ['independence', 'may', 'be', 'important', 'because', 'my', 'sister'],
#  ['independence', 'may', 'be', 'important', 'because', 'my', 'brother'],
#  ['independence', 'may', 'be', 'important', 'because', 'my', 'mother'],
#  ['independence', 'may', 'be', 'important', 'because', 'my', 'father'],
#  ['independence', 'may', 'be', 'important', 'because', 'my', 'cousin'],
#  ['independence', 'may', 'be', 'important', 'because', 'my', 'aunt'],
#  ['independence', 'may', 'be', 'important', 'because', 'my', 'uncle'],
#  ['independence', 'important', 'because', 'my', 'friends'],
#  ['independence', 'important', 'because', 'my', 'family'],
#  ['independence', 'important', 'because', 'my', 'grandparents'],
#  ['independence', 'important', 'because', 'my', 'parents'],
#  ['independence', 'important', 'because', 'my', 'teacher'],
#  ['independence', 'important', 'because', 'my', 'friend'],
#  ['independence', 'important', 'because', 'my', 'dad'],
#  ['independence', 'important', 'because', 'my', 'mom'],
#  ['independence', 'important', 'because', 'my', 'sister'],
#  ['independence', 'important', 'because', 'my', 'brother'],
#  ['independence', 'important', 'because', 'my', 'mother'],
#  ['independence', 'important', 'because', 'my', 'father'],
#  ['independence', 'important', 'because', 'my', 'cousin'],
#  ['independence', 'important', 'because', 'my', 'aunt'],
# ...
#  ['social',
#   'groups',
#   'should',
#   'be',
#   'important',
#   'because',
#   'my',
#   'grandparents'],
#  ['social', 'groups', 'should', 'be', 'important', 'because', 'my', 'parents'],
#  ['social', 'groups', 'should', 'be', 'important', 'because', 'my', 'teacher'],
#  ['social', 'groups', 'should', 'be', 'important', 'because', 'my', 'friend'],
#  ['social', 'groups', 'should', 'be', 'important', 'because', 'my', 'dad'],
#  ['social', 'groups', 'should', 'be', 'important', 'because', 'my', 'mom'],
#  ['social', 'groups', 'should', 'be', 'important', 'because', 'my', 'sister'],
#  ['social', 'groups', 'should', 'be', 'important', 'because', 'my', 'brother'],
#  ['social', 'groups', 'should', 'be', 'important', 'because', 'my', 'mother'],
#  ['social', 'groups', 'should', 'be', 'important', 'because', 'my', 'father'],
#  ['social', 'groups', 'should', 'be', 'important', 'because', 'my', 'cousin'],
#  ['social', 'groups', 'should', 'be', 'important', 'because', 'my', 'aunt'],
#  ['social', 'groups', 'should', 'be', 'important', 'because', 'my', 'uncle'],
#  ['social', 'groups', 'may', 'be', 'important', 'because', 'my', 'friends'],
#  ['social', 'groups', 'may', 'be', 'important', 'because', 'my', 'family'],
#  ['social',
#   'groups',
#   'may',
#   'be',
#   'important',
#   'because',
#   'my',
#   'grandparents'],
#  ['social', 'groups', 'may', 'be', 'important', 'because', 'my', 'parents'],
#  ['social', 'groups', 'may', 'be', 'important', 'because', 'my', 'teacher'],
#  ['social', 'groups', 'may', 'be', 'important', 'because', 'my', 'friend'],
#  ['social', 'groups', 'may', 'be', 'important', 'because', 'my', 'dad'],
#  ['social', 'groups', 'may', 'be', 'important', 'because', 'my', 'mom'],
#  ['social', 'groups', 'may', 'be', 'important', 'because', 'my', 'sister'],
#  ['social', 'groups', 'may', 'be', 'important', 'because', 'my', 'brother'],
#  ['social', 'groups', 'may', 'be', 'important', 'because', 'my', 'mother'],
#  ['social', 'groups', 'may', 'be', 'important', 'because', 'my', 'father'],
#  ['social', 'groups', 'may', 'be', 'important', 'because', 'my', 'cousin'],
#  ['social', 'groups', 'may', 'be', 'important', 'because', 'my', 'aunt'],
#  ['social', 'groups', 'may', 'be', 'important', 'because', 'my', 'uncle'],
#  ['social', 'groups', 'important', 'because', 'my', 'friends'],
#  ['social', 'groups', 'important', 'because', 'my', 'family'],
#  ['social', 'groups', 'important', 'because', 'my', 'grandparents'],
#  ['social', 'groups', 'important', 'because', 'my', 'parents'],
#  ['social', 'groups', 'important', 'because', 'my', 'teacher'],
#  ['social', 'groups', 'important', 'because', 'my', 'friend'],
#  ['social', 'groups', 'important', 'because', 'my', 'dad'],
#  ['social', 'groups', 'important', 'because', 'my', 'mom'],
#  ['social', 'groups', 'important', 'because', 'my', 'sister'],
#  ['social', 'groups', 'important', 'because', 'my', 'brother'],
#  ['social', 'groups', 'important', 'because', 'my', 'mother'],
#  ['social', 'groups', 'important', 'because', 'my', 'father'],
#  ['social', 'groups', 'important', 'because', 'my', 'cousin'],
#  ['social', 'groups', 'important', 'because', 'my', 'aunt'],
#  ['social', 'groups', 'important', 'because', 'my', 'uncle'],
#  ['social', 'groups', 'important', 'because', 'my', 'friends'],
#  ['social', 'groups', 'important', 'because', 'my', 'family'],
#  ['social', 'groups', 'important', 'because', 'my', 'grandparents'],
#  ['social', 'groups', 'important', 'because', 'my', 'parents'],
#  ['social', 'groups', 'important', 'because', 'my', 'teacher'],
#  ['social', 'groups', 'important', 'because', 'my', 'friend'],
#  ['social', 'groups', 'important', 'because', 'my', 'dad'],
#  ['social', 'groups', 'important', 'because', 'my', 'mom'],
#  ['social', 'groups', 'important', 'because', 'my', 'sister'],
#  ['social', 'groups', 'important', 'because', 'my', 'brother'],
#  ['social', 'groups', 'important', 'because', 'my', 'mother'],
#  ['social', 'groups', 'important', 'because', 'my', 'father'],
#  ['social', 'groups', 'important', 'because', 'my', 'cousin'],
#  ['social', 'groups', 'important', 'because', 'my', 'aunt'],
#  ['social', 'groups', 'important', 'because', 'my', 'uncle'],
#  ['social', 'groups', 'important', 'because', 'my', 'friends'],
#  ['social', 'groups', 'important', 'because', 'my', 'family'],
#  ['social', 'groups', 'important', 'because', 'my', 'grandparents'],
#  ['social', 'groups', 'important', 'because', 'my', 'parents'],
#  ['social', 'groups', 'important', 'because', 'my', 'teacher'],
#  ['social', 'groups', 'important', 'because', 'my', 'friend'],
#  ['social', 'groups', 'important', 'because', 'my', 'dad'],
#  ['social', 'groups', 'important', 'because', 'my', 'mom'],
#  ['social', 'groups', 'important', 'because', 'my', 'sister'],
#  ['social', 'groups', 'important', 'because', 'my', 'brother'],
#  ['social', 'groups', 'important', 'because', 'my', 'mother'],
#  ['social', 'groups', 'important', 'because', 'my', 'father'],
#  ['social', 'groups', 'important', 'because', 'my', 'cousin'],
#  ['social', 'groups', 'important', 'because', 'my', 'aunt'],
#  ['social', 'groups', 'important', 'because', 'my', 'uncle'],
#  ['social', 'groups', 'important', 'because', 'my', 'friends'],
#  ['social', 'groups', 'important', 'because', 'my', 'family'],
#  ['social', 'groups', 'important', 'because', 'my', 'grandparents'],
#  ['social', 'groups', 'important', 'because', 'my', 'parents'],
#  ['social', 'groups', 'important', 'because', 'my', 'teacher'],
#  ['social', 'groups', 'important', 'because', 'my', 'friend'],
#  ['social', 'groups', 'important', 'because', 'my', 'dad'],
#  ['social', 'groups', 'important', 'because', 'my', 'mom'],
#  ['social', 'groups', 'important', 'because', 'my', 'sister'],
#  ['social', 'groups', 'important', 'because', 'my', 'brother'],
#  ['social', 'groups', 'important', 'because', 'my', 'mother'],
#  ['social', 'groups', 'important', 'because', 'my', 'father'],
#  ['social', 'groups', 'important', 'because', 'my', 'cousin'],
#  ['social', 'groups', 'important', 'because', 'my', 'aunt'],
#  ['social', 'groups', 'important', 'because', 'my', 'uncle'],
#  ['music', 'might', 'be', 'important', 'because', 'my', 'friends'],
#  ['music', 'might', 'be', 'important', 'because', 'my', 'family'],
#  ['music', 'might', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['music', 'might', 'be', 'important', 'because', 'my', 'parents'],
#  ['music', 'might', 'be', 'important', 'because', 'my', 'teacher'],
#  ['music', 'might', 'be', 'important', 'because', 'my', 'friend'],
#  ['music', 'might', 'be', 'important', 'because', 'my', 'dad'],
#  ['music', 'might', 'be', 'important', 'because', 'my', 'mom'],
#  ['music', 'might', 'be', 'important', 'because', 'my', 'sister'],
#  ['music', 'might', 'be', 'important', 'because', 'my', 'brother'],
#  ['music', 'might', 'be', 'important', 'because', 'my', 'mother'],
#  ['music', 'might', 'be', 'important', 'because', 'my', 'father'],
#  ['music', 'might', 'be', 'important', 'because', 'my', 'cousin'],
#  ['music', 'might', 'be', 'important', 'because', 'my', 'aunt'],
#  ['music', 'might', 'be', 'important', 'because', 'my', 'uncle'],
#  ['music', 'could', 'be', 'important', 'because', 'my', 'friends'],
#  ['music', 'could', 'be', 'important', 'because', 'my', 'family'],
#  ['music', 'could', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['music', 'could', 'be', 'important', 'because', 'my', 'parents'],
#  ['music', 'could', 'be', 'important', 'because', 'my', 'teacher'],
#  ['music', 'could', 'be', 'important', 'because', 'my', 'friend'],
#  ['music', 'could', 'be', 'important', 'because', 'my', 'dad'],
#  ['music', 'could', 'be', 'important', 'because', 'my', 'mom'],
#  ['music', 'could', 'be', 'important', 'because', 'my', 'sister'],
#  ['music', 'could', 'be', 'important', 'because', 'my', 'brother'],
#  ['music', 'could', 'be', 'important', 'because', 'my', 'mother'],
#  ['music', 'could', 'be', 'important', 'because', 'my', 'father'],
#  ['music', 'could', 'be', 'important', 'because', 'my', 'cousin'],
#  ['music', 'could', 'be', 'important', 'because', 'my', 'aunt'],
#  ['music', 'could', 'be', 'important', 'because', 'my', 'uncle'],
#  ['music', 'should', 'be', 'important', 'because', 'my', 'friends'],
#  ['music', 'should', 'be', 'important', 'because', 'my', 'family'],
#  ['music', 'should', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['music', 'should', 'be', 'important', 'because', 'my', 'parents'],
#  ['music', 'should', 'be', 'important', 'because', 'my', 'teacher'],
#  ['music', 'should', 'be', 'important', 'because', 'my', 'friend'],
#  ['music', 'should', 'be', 'important', 'because', 'my', 'dad'],
#  ['music', 'should', 'be', 'important', 'because', 'my', 'mom'],
#  ['music', 'should', 'be', 'important', 'because', 'my', 'sister'],
#  ['music', 'should', 'be', 'important', 'because', 'my', 'brother'],
#  ['music', 'should', 'be', 'important', 'because', 'my', 'mother'],
#  ['music', 'should', 'be', 'important', 'because', 'my', 'father'],
#  ['music', 'should', 'be', 'important', 'because', 'my', 'cousin'],
#  ['music', 'should', 'be', 'important', 'because', 'my', 'aunt'],
#  ['music', 'should', 'be', 'important', 'because', 'my', 'uncle'],
#  ['music', 'may', 'be', 'important', 'because', 'my', 'friends'],
#  ['music', 'may', 'be', 'important', 'because', 'my', 'family'],
#  ['music', 'may', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['music', 'may', 'be', 'important', 'because', 'my', 'parents'],
#  ['music', 'may', 'be', 'important', 'because', 'my', 'teacher'],
#  ['music', 'may', 'be', 'important', 'because', 'my', 'friend'],
#  ['music', 'may', 'be', 'important', 'because', 'my', 'dad'],
#  ['music', 'may', 'be', 'important', 'because', 'my', 'mom'],
#  ['music', 'may', 'be', 'important', 'because', 'my', 'sister'],
#  ['music', 'may', 'be', 'important', 'because', 'my', 'brother'],
#  ['music', 'may', 'be', 'important', 'because', 'my', 'mother'],
#  ['music', 'may', 'be', 'important', 'because', 'my', 'father'],
#  ['music', 'may', 'be', 'important', 'because', 'my', 'cousin'],
#  ['music', 'may', 'be', 'important', 'because', 'my', 'aunt'],
#  ['music', 'may', 'be', 'important', 'because', 'my', 'uncle'],
#  ['music', 'important', 'because', 'my', 'friends'],
#  ['music', 'important', 'because', 'my', 'family'],
#  ['music', 'important', 'because', 'my', 'grandparents'],
#  ['music', 'important', 'because', 'my', 'parents'],
#  ['music', 'important', 'because', 'my', 'teacher'],
#  ['music', 'important', 'because', 'my', 'friend'],
#  ['music', 'important', 'because', 'my', 'dad'],
#  ['music', 'important', 'because', 'my', 'mom'],
#  ['music', 'important', 'because', 'my', 'sister'],
#  ['music', 'important', 'because', 'my', 'brother'],
#  ['music', 'important', 'because', 'my', 'mother'],
#  ['music', 'important', 'because', 'my', 'father'],
#  ['music', 'important', 'because', 'my', 'cousin'],
#  ['music', 'important', 'because', 'my', 'aunt'],
#  ['music', 'important', 'because', 'my', 'uncle'],
#  ['music', 'important', 'because', 'my', 'friends'],
#  ['music', 'important', 'because', 'my', 'family'],
#  ['music', 'important', 'because', 'my', 'grandparents'],
#  ['music', 'important', 'because', 'my', 'parents'],
#  ['music', 'important', 'because', 'my', 'teacher'],
#  ['music', 'important', 'because', 'my', 'friend'],
#  ['music', 'important', 'because', 'my', 'dad'],
#  ['music', 'important', 'because', 'my', 'mom'],
#  ['music', 'important', 'because', 'my', 'sister'],
#  ['music', 'important', 'because', 'my', 'brother'],
#  ['music', 'important', 'because', 'my', 'mother'],
#  ['music', 'important', 'because', 'my', 'father'],
#  ['music', 'important', 'because', 'my', 'cousin'],
#  ['music', 'important', 'because', 'my', 'aunt'],
#  ['music', 'important', 'because', 'my', 'uncle'],
#  ['music', 'important', 'because', 'my', 'friends'],
#  ['music', 'important', 'because', 'my', 'family'],
#  ['music', 'important', 'because', 'my', 'grandparents'],
#  ['music', 'important', 'because', 'my', 'parents'],
#  ['music', 'important', 'because', 'my', 'teacher'],
#  ['music', 'important', 'because', 'my', 'friend'],
#  ['music', 'important', 'because', 'my', 'dad'],
#  ['music', 'important', 'because', 'my', 'mom'],
#  ['music', 'important', 'because', 'my', 'sister'],
#  ['music', 'important', 'because', 'my', 'brother'],
#  ['music', 'important', 'because', 'my', 'mother'],
#  ['music', 'important', 'because', 'my', 'father'],
#  ['music', 'important', 'because', 'my', 'cousin'],
#  ['music', 'important', 'because', 'my', 'aunt'],
#  ['music', 'important', 'because', 'my', 'uncle'],
#  ['music', 'important', 'because', 'my', 'friends'],
#  ['music', 'important', 'because', 'my', 'family'],
#  ['music', 'important', 'because', 'my', 'grandparents'],
#  ['music', 'important', 'because', 'my', 'parents'],
#  ['music', 'important', 'because', 'my', 'teacher'],
#  ['music', 'important', 'because', 'my', 'friend'],
#  ['music', 'important', 'because', 'my', 'dad'],
#  ['music', 'important', 'because', 'my', 'mom'],
#  ['music', 'important', 'because', 'my', 'sister'],
#  ['music', 'important', 'because', 'my', 'brother'],
#  ['music', 'important', 'because', 'my', 'mother'],
#  ['music', 'important', 'because', 'my', 'father'],
#  ['music', 'important', 'because', 'my', 'cousin'],
#  ['music', 'important', 'because', 'my', 'aunt'],
#  ['music', 'important', 'because', 'my', 'uncle'],
#  ['politics', 'might', 'be', 'important', 'because', 'my', 'friends'],
#  ['politics', 'might', 'be', 'important', 'because', 'my', 'family'],
#  ['politics', 'might', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['politics', 'might', 'be', 'important', 'because', 'my', 'parents'],
#  ['politics', 'might', 'be', 'important', 'because', 'my', 'teacher'],
#  ['politics', 'might', 'be', 'important', 'because', 'my', 'friend'],
#  ['politics', 'might', 'be', 'important', 'because', 'my', 'dad'],
#  ['politics', 'might', 'be', 'important', 'because', 'my', 'mom'],
#  ['politics', 'might', 'be', 'important', 'because', 'my', 'sister'],
#  ['politics', 'might', 'be', 'important', 'because', 'my', 'brother'],
#  ['politics', 'might', 'be', 'important', 'because', 'my', 'mother'],
#  ['politics', 'might', 'be', 'important', 'because', 'my', 'father'],
#  ['politics', 'might', 'be', 'important', 'because', 'my', 'cousin'],
#  ['politics', 'might', 'be', 'important', 'because', 'my', 'aunt'],
#  ['politics', 'might', 'be', 'important', 'because', 'my', 'uncle'],
#  ['politics', 'could', 'be', 'important', 'because', 'my', 'friends'],
#  ['politics', 'could', 'be', 'important', 'because', 'my', 'family'],
#  ['politics', 'could', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['politics', 'could', 'be', 'important', 'because', 'my', 'parents'],
#  ['politics', 'could', 'be', 'important', 'because', 'my', 'teacher'],
#  ['politics', 'could', 'be', 'important', 'because', 'my', 'friend'],
#  ['politics', 'could', 'be', 'important', 'because', 'my', 'dad'],
#  ['politics', 'could', 'be', 'important', 'because', 'my', 'mom'],
#  ['politics', 'could', 'be', 'important', 'because', 'my', 'sister'],
#  ['politics', 'could', 'be', 'important', 'because', 'my', 'brother'],
#  ['politics', 'could', 'be', 'important', 'because', 'my', 'mother'],
#  ['politics', 'could', 'be', 'important', 'because', 'my', 'father'],
#  ['politics', 'could', 'be', 'important', 'because', 'my', 'cousin'],
#  ['politics', 'could', 'be', 'important', 'because', 'my', 'aunt'],
#  ['politics', 'could', 'be', 'important', 'because', 'my', 'uncle'],
#  ['politics', 'should', 'be', 'important', 'because', 'my', 'friends'],
#  ['politics', 'should', 'be', 'important', 'because', 'my', 'family'],
#  ['politics', 'should', 'be', 'important', 'because', 'my', 'grandparents'],
#  ['politics', 'should', 'be', 'important', 'because', 'my', 'parents'],
#  ['politics', 'should', 'be', 'important', 'because', 'my', 'teacher'],
#  ['politics', 'should', 'be', 'important', 'because', 'my', 'friend'],
#  ['politics', 'should', 'be', 'important', 'because', 'my', 'dad'],
#  ['politics', 'should', 'be', 'important', 'because', 'my', 'mom'],
#  ['politics', 'should', 'be', 'important', 'because', 'my', 'sister'],
#  ['politics', 'should', 'be', 'important', 'because', 'my', 'brother'],
#  ...]

# %%
df.head()
# Out:
#   justification modifier                                               text  \
# 0       friends    might  Athletic ability might be important because my...
# 1        family    might  Athletic ability might be important because my...
# 2  grandparents    might  Athletic ability might be important because my...
# 3       parents    might  Athletic ability might be important because my...
# 4       teacher    might  Athletic ability might be important because my...
#
#       value modif_type
# 0  Athletic  uncertain
# 1  Athletic  uncertain
# 2  Athletic  uncertain
# 3  Athletic  uncertain
# 4  Athletic  uncertain
